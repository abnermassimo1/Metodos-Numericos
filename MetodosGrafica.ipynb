# %% [markdown]
# <a href="https://colab.research.google.com/github/abnermassimo1/Metodos-Numericos/blob/main/MetodosGrafica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color=red>METODOS-NUMERICOS</font>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Grafica de la ecuacion: $$ y = x^2 $$

# %%
x = np.linspace(-3,3)
def square(x): return x**2
y = square(x)

plt.plot(x,y)

# %% [markdown]
# ![grafico_parabola.png](data:image/png;base64,...)
